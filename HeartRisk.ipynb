# %% [raw]
# # Heart Disease Prediction
#
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.pylabtools import figsize
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score , recall_score , f1_score
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

from collections import Counter

plt.style.use("fivethirtyeight")

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"/Users/ghadeerhani/Downloads/heart_disease_risk_2026.csv")

# %% [markdown]
# ## 3. Data Exploration

# %%
data.head()
# Out:
#    patient_id  age     sex  resting_bp_systolic  resting_bp_diastolic  \
# 0           1   44    Male                  117                    74
# 1           2   57    Male                  139                    94
# 2           3   29    Male                  128                    78
# 3           4   72    Male                  132                    86
# 4           5   62  Female                  116                    75
#
#    cholesterol_total  hdl  ldl  triglycerides  fasting_blood_sugar  ...  \
# 0                193   57  106            119                  112  ...
# 1                185   69  110             35                  114  ...
# 2                197   52  108            157                   95  ...
# 3                197   59  104            143                   92  ...
# 4                154   65   75            104                  135  ...
#
#    family_history  smoker_status  alcohol_units_per_week  \
# 0           False          Never                     2.9
# 1           False          Never                     3.0
# 2           False        Current                     3.5
# 3           False          Never                     2.7
# 4            True         Former                     3.3
#
#    exercise_minutes_per_week sleep_hours  stress_score  wearable_owner  \
# 0                         86         5.4          19.8            True
# 1                        132         4.3          45.8            True
# 2                        128         5.1          17.7            True
# 3                         18         6.8          63.6            True
# 4                         24         8.2          58.7           False
#
#    daily_steps diet_quality_score  has_heart_disease
# 0         7731               62.9                  0
# 1         2629               74.6                  1
# 2         9290               65.7                  0
# 3         7373               48.5                  1
# 4         6331               47.3                  1
#
# [5 rows x 27 columns]

# %%
data = data.drop('patient_id', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        9000 non-null   int64
#  1   sex                        9000 non-null   str
#  2   resting_bp_systolic        9000 non-null   int64
#  3   resting_bp_diastolic       9000 non-null   int64
#  4   cholesterol_total          9000 non-null   int64
#  5   hdl                        9000 non-null   int64
#  6   ldl                        9000 non-null   int64
#  7   triglycerides              9000 non-null   int64
#  8   fasting_blood_sugar        9000 non-null   int64
#  9   hba1c                      9000 non-null   float64
#  10  bmi                        9000 non-null   float64
#  11  resting_heart_rate         9000 non-null   int64
#  12  max_heart_rate_achieved    9000 non-null   int64
#  13  chest_pain_type            9000 non-null   str
#  14  exercise_induced_angina    9000 non-null   bool
#  15  st_depression              9000 non-null   float64
#  16  family_history             9000 non-null   bool
#  17  smoker_status              9000 non-null   str
#  18  alcohol_units_per_week     9000 non-null   float64
#  19  exercise_minutes_per_week  9000 non-null   int64
#  20  sleep_hours                9000 non-null   float64
#  21  stress_score               9000 non-null   float64
#  22  wearable_owner             9000 non-null   bool
#  23  daily_steps                9000 non-null   int64
#  24  diet_quality_score         9000 non-null   float64
#  25  has_heart_disease          9000 non-null   int64
# dtypes: bool(3), float64(7), int64(13), str(3)
# memory usage: 1.6 MB

# %%
data.describe()
# Out:
#                age  resting_bp_systolic  resting_bp_diastolic  \
# count  9000.000000          9000.000000           9000.000000
# mean     53.977333           127.849778             80.788778
# std      13.008051            13.767233             10.939943
# min      18.000000            85.000000             50.000000
# 25%      45.000000           119.000000             74.000000
# 50%      54.000000           128.000000             81.000000
# 75%      63.000000           137.000000             88.000000
# max      90.000000           181.000000            126.000000
#
#        cholesterol_total          hdl          ldl  triglycerides  \
# count        9000.000000  9000.000000  9000.000000    9000.000000
# mean          188.753556    55.215333   103.275556     152.045000
# std            32.271644    12.394400    27.342198      51.448384
# min            90.000000    18.000000    35.000000      35.000000
# 25%           167.000000    47.000000    85.000000     117.000000
# 50%           189.000000    55.000000   103.000000     151.000000
# 75%           211.000000    64.000000   122.000000     186.000000
# max           314.000000   110.000000   207.000000     390.000000
#
#        fasting_blood_sugar        hba1c          bmi  resting_heart_rate  \
# count          9000.000000  9000.000000  9000.000000         9000.000000
# mean            119.470444     5.791633    25.264922           80.912667
# std              22.778082     0.692645     4.371525            8.604685
# min              60.000000     4.000000    15.000000           48.000000
# 25%             104.000000     5.300000    22.300000           75.000000
# 50%             119.000000     5.800000    25.300000           81.000000
# 75%             135.000000     6.300000    28.200000           87.000000
# max             204.000000     8.600000    43.300000          111.000000
#
#        max_heart_rate_achieved  st_depression  alcohol_units_per_week  \
# count              9000.000000    9000.000000             9000.000000
# mean                164.838333       1.012911                5.708733
# std                  21.290773       0.957090                5.070642
# min                  93.000000       0.000000                0.000000
# 25%                 150.000000       0.400000                2.200000
# 50%                 166.000000       0.700000                4.200000
# 75%                 180.000000       1.400000                7.700000
# max                 210.000000       6.500000               45.900000
#
#        exercise_minutes_per_week  sleep_hours  stress_score   daily_steps  \
# count                9000.000000  9000.000000   9000.000000   9000.000000
# mean                  139.493444     6.994578     47.968033   6163.659333
# std                    63.660433     1.104215     16.162484   2170.685995
# min                     0.000000     3.100000      0.000000    500.000000
# 25%                    96.000000     6.300000     37.100000   4658.000000
# 50%                   139.000000     7.000000     48.100000   6178.000000
# 75%                   183.000000     7.700000     58.900000   7632.750000
# max                   366.000000    11.000000    100.000000  13950.000000
#
#        diet_quality_score  has_heart_disease
# count         9000.000000        9000.000000
# mean            59.467400           0.303000
# std             14.476064           0.459581
# min              4.800000           0.000000
# 25%             49.700000           0.000000
# 50%             59.600000           0.000000
# 75%             69.100000           1.000000
# max            100.000000           1.000000

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.corr(numeric_only=True)
# Out:
#                                 age  resting_bp_systolic  \
# age                        1.000000             0.417806
# resting_bp_systolic        0.417806             1.000000
# resting_bp_diastolic       0.325367             0.767131
# cholesterol_total          0.127731             0.103243
# hdl                       -0.044404            -0.099598
# ldl                        0.162302             0.125662
# triglycerides              0.011041             0.088658
# fasting_blood_sugar        0.143855             0.123649
# hba1c                      0.156264             0.142820
# bmi                        0.039013             0.267527
# resting_heart_rate         0.054694             0.107173
# max_heart_rate_achieved   -0.730663            -0.373345
# exercise_induced_angina    0.132967             0.115015
# st_depression              0.091256             0.082864
# family_history            -0.009774            -0.001879
# alcohol_units_per_week    -0.006700             0.080252
# exercise_minutes_per_week -0.177415            -0.208676
# sleep_hours                0.012247            -0.012507
# stress_score               0.034727             0.166701
# wearable_owner            -0.014010            -0.068382
# daily_steps               -0.179010            -0.127868
# diet_quality_score        -0.029748            -0.059250
# has_heart_disease          0.290954             0.249089
#
#                            resting_bp_diastolic  cholesterol_total       hdl  \
# age                                    0.325367           0.127731 -0.044404
# resting_bp_systolic                    0.767131           0.103243 -0.099598
# resting_bp_diastolic                   1.000000           0.078116 -0.072862
# cholesterol_total                      0.078116           1.000000  0.287822
# hdl                                   -0.072862           0.287822  1.000000
# ldl                                    0.091444           0.841361 -0.082460
# triglycerides                          0.074779           0.347647 -0.084219
# fasting_blood_sugar                    0.086416           0.050895 -0.075956
# hba1c                                  0.103883           0.060513 -0.083552
# bmi                                    0.204737           0.155636 -0.240855
# resting_heart_rate                     0.085644           0.027943 -0.124171
# max_heart_rate_achieved               -0.292709          -0.134094  0.145244
# exercise_induced_angina                0.093085           0.070051 -0.114853
# st_depression                          0.065295           0.054714 -0.095251
# family_history                        -0.002945           0.004472  0.008457
# alcohol_units_per_week                 0.067402           0.052598 -0.025416
# exercise_minutes_per_week             -0.163231           0.027857  0.284646
# sleep_hours                           -0.028537          -0.011633 -0.012647
# stress_score                           0.127810          -0.023361 -0.055353
# wearable_owner                        -0.067608           0.017032  0.100494
# daily_steps                           -0.109219           0.009008  0.112247
# diet_quality_score                    -0.052303          -0.151784  0.170579
# has_heart_disease                      0.193104           0.167516 -0.251505
#
#                                 ldl  triglycerides  fasting_blood_sugar  \
# age                        0.162302       0.011041             0.143855
# resting_bp_systolic        0.125662       0.088658             0.123649
# resting_bp_diastolic       0.091444       0.074779             0.086416
# cholesterol_total          0.841361       0.347647             0.050895
# hdl                       -0.082460      -0.084219            -0.075956
# ldl                        1.000000       0.069901             0.062252
# triglycerides              0.069901       1.000000             0.079961
# fasting_blood_sugar        0.062252       0.079961             1.000000
# hba1c                      0.070964       0.091954             0.877319
# bmi                        0.181230       0.284031             0.228646
# resting_heart_rate         0.073291       0.060883             0.089703
# max_heart_rate_achieved   -0.203980      -0.051328            -0.180248
# exercise_induced_angina    0.117103       0.053931             0.091387
# st_depression              0.092348       0.040409             0.085624
# family_history             0.011833      -0.014089            -0.011631
# alcohol_units_per_week    -0.017613       0.234464            -0.003454
# exercise_minutes_per_week -0.075009      -0.054478            -0.168518
# sleep_hours               -0.006498      -0.003284            -0.006272
# stress_score              -0.001160       0.005444             0.024338
# wearable_owner            -0.024300      -0.004180            -0.055280
# daily_steps               -0.029117      -0.019219            -0.064678
# diet_quality_score        -0.191114      -0.173407            -0.050234
# has_heart_disease          0.267150       0.110365             0.202358
#
#                               hba1c       bmi  ...  st_depression  \
# age                        0.156264  0.039013  ...       0.091256
# resting_bp_systolic        0.142820  0.267527  ...       0.082864
# resting_bp_diastolic       0.103883  0.204737  ...       0.065295
# cholesterol_total          0.060513  0.155636  ...       0.054714
# hdl                       -0.083552 -0.240855  ...      -0.095251
# ldl                        0.070964  0.181230  ...       0.092348
# triglycerides              0.091954  0.284031  ...       0.040409
# fasting_blood_sugar        0.877319  0.228646  ...       0.085624
# hba1c                      1.000000  0.251839  ...       0.093673
# bmi                        0.251839  1.000000  ...       0.072929
# resting_heart_rate         0.097153  0.184545  ...       0.057417
# max_heart_rate_achieved   -0.197522 -0.122960  ...      -0.197003
# exercise_induced_angina    0.107934  0.085095  ...       0.161382
# st_depression              0.093673  0.072929  ...       1.000000
# family_history            -0.014516 -0.011292  ...       0.027105
# alcohol_units_per_week     0.004729 -0.014097  ...       0.026458
# exercise_minutes_per_week -0.191007 -0.192731  ...      -0.091698
# sleep_hours               -0.005381 -0.013262  ...      -0.022662
# stress_score               0.026944  0.032952  ...       0.022954
# wearable_owner            -0.062126 -0.072421  ...      -0.029158
# daily_steps               -0.072347 -0.084183  ...      -0.034226
# diet_quality_score        -0.052664 -0.108692  ...      -0.046607
# has_heart_disease          0.225830  0.213249  ...       0.356817
#
#                            family_history  alcohol_units_per_week  \
# age                             -0.009774               -0.006700
# resting_bp_systolic             -0.001879                0.080252
# resting_bp_diastolic            -0.002945                0.067402
# cholesterol_total                0.004472                0.052598
# hdl                              0.008457               -0.025416
# ldl                              0.011833               -0.017613
# triglycerides                   -0.014089                0.234464
# fasting_blood_sugar             -0.011631               -0.003454
# hba1c                           -0.014516                0.004729
# bmi                             -0.011292               -0.014097
# resting_heart_rate              -0.008378                0.002273
# max_heart_rate_achieved         -0.021002               -0.006069
# exercise_induced_angina          0.044668                0.026358
# st_depression                    0.027105                0.026458
# family_history                   1.000000               -0.008314
# alcohol_units_per_week          -0.008314                1.000000
# exercise_minutes_per_week        0.012632               -0.005085
# sleep_hours                     -0.005742               -0.010092
# stress_score                    -0.001040                0.009576
# wearable_owner                   0.001662                0.017290
# daily_steps                     -0.005538                0.013100
# diet_quality_score               0.012407               -0.020080
# has_heart_disease                0.070622                0.041271
#
#                            exercise_minutes_per_week  sleep_hours  \
# age                                        -0.177415     0.012247
# resting_bp_systolic                        -0.208676    -0.012507
# resting_bp_diastolic                       -0.163231    -0.028537
# cholesterol_total                           0.027857    -0.011633
# hdl                                         0.284646    -0.012647
# ldl                                        -0.075009    -0.006498
# triglycerides                              -0.054478    -0.003284
# fasting_blood_sugar                        -0.168518    -0.006272
# hba1c                                      -0.191007    -0.005381
# bmi                                        -0.192731    -0.013262
# resting_heart_rate                         -0.305317    -0.021408
# max_heart_rate_achieved                     0.294445     0.023679
# exercise_induced_angina                    -0.111356    -0.026056
# st_depression                              -0.091698    -0.022662
# family_history                              0.012632    -0.005742
# alcohol_units_per_week                     -0.005085    -0.010092
# exercise_minutes_per_week                   1.000000     0.030109
# sleep_hours                                 0.030109     1.000000
# stress_score                               -0.139662    -0.001830
# wearable_owner                              0.355277     0.081018
# daily_steps                                 0.406385     0.023210
# diet_quality_score                          0.166613     0.007267
# has_heart_disease                          -0.248475    -0.049797
#
#                            stress_score  wearable_owner  daily_steps  \
# age                            0.034727       -0.014010    -0.179010
# resting_bp_systolic            0.166701       -0.068382    -0.127868
# resting_bp_diastolic           0.127810       -0.067608    -0.109219
# cholesterol_total             -0.023361        0.017032     0.009008
# hdl                           -0.055353        0.100494     0.112247
# ldl                           -0.001160       -0.024300    -0.029117
# triglycerides                  0.005444       -0.004180    -0.019219
# fasting_blood_sugar            0.024338       -0.055280    -0.064678
# hba1c                          0.026944       -0.062126    -0.072347
# bmi                            0.032952       -0.072421    -0.084183
# resting_heart_rate             0.157412       -0.108281    -0.100720
# max_heart_rate_achieved       -0.076187        0.072071     0.207887
# exercise_induced_angina        0.052205       -0.035134    -0.068522
# st_depression                  0.022954       -0.029158    -0.034226
# family_history                -0.001040        0.001662    -0.005538
# alcohol_units_per_week         0.009576        0.017290     0.013100
# exercise_minutes_per_week     -0.139662        0.355277     0.406385
# sleep_hours                   -0.001830        0.081018     0.023210
# stress_score                   1.000000       -0.066679    -0.051596
# wearable_owner                -0.066679        1.000000     0.467535
# daily_steps                   -0.051596        0.467535     1.000000
# diet_quality_score            -0.021072        0.066230     0.068543
# has_heart_disease              0.097975       -0.094652    -0.152855
#
#                            diet_quality_score  has_heart_disease
# age                                 -0.029748           0.290954
# resting_bp_systolic                 -0.059250           0.249089
# resting_bp_diastolic                -0.052303           0.193104
# cholesterol_total                   -0.151784           0.167516
# hdl                                  0.170579          -0.251505
# ldl                                 -0.191114           0.267150
# triglycerides                       -0.173407           0.110365
# fasting_blood_sugar                 -0.050234           0.202358
# hba1c                               -0.052664           0.225830
# bmi                                 -0.108692           0.213249
# resting_heart_rate                  -0.093902           0.168212
# max_heart_rate_achieved              0.090322          -0.580704
# exercise_induced_angina             -0.082211           0.445412
# st_depression                       -0.046607           0.356817
# family_history                       0.012407           0.070622
# alcohol_units_per_week              -0.020080           0.041271
# exercise_minutes_per_week            0.166613          -0.248475
# sleep_hours                          0.007267          -0.049797
# stress_score                        -0.021072           0.097975
# wearable_owner                       0.066230          -0.094652
# daily_steps                          0.068543          -0.152855
# diet_quality_score                   1.000000          -0.155234
# has_heart_disease                   -0.155234           1.000000
#
# [23 rows x 23 columns]

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(numeric_only=True),annot=True,fmt="0.1f",linewidths=.5)
# Out:
# <Axes: >

# %%
sns.countplot(x="has_heart_disease",data=data)
# Out:
# <Axes: xlabel='has_heart_disease', ylabel='count'>

# %%
maxi=data[data["has_heart_disease"]==0]
mini=data[data["has_heart_disease"]==1]
maxi.shape ,mini.shape
2727/(6273+2727)
# Out:
# 0.303

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.histplot(data["age"], kde=True)
plt.title("Age Distribution")

plt.subplot(1,3,2)
sns.countplot(x="has_heart_disease", data=data)
plt.title("Heart Disease Count")

plt.subplot(1,3,3)
sns.boxplot(x="has_heart_disease", y="age", data=data)
plt.title("Age vs Heart Disease")

plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['age', 'sex', 'resting_bp_systolic', 'resting_bp_diastolic',
#        'cholesterol_total', 'hdl', 'ldl', 'triglycerides',
#        'fasting_blood_sugar', 'hba1c', 'bmi', 'resting_heart_rate',
#        'max_heart_rate_achieved', 'chest_pain_type', 'exercise_induced_angina',
#        'st_depression', 'family_history', 'smoker_status',
#        'alcohol_units_per_week', 'exercise_minutes_per_week', 'sleep_hours',
#        'stress_score', 'wearable_owner', 'daily_steps', 'diet_quality_score',
#        'has_heart_disease'],
#       dtype='str')

# %%
data = pd.get_dummies(
    data,
    columns=["sex", "chest_pain_type", "smoker_status"],
    drop_first=True
)

# %%
x= data.drop("has_heart_disease",axis=1)
y = data["has_heart_disease"]

# %%
rm=RandomOverSampler(random_state=41)
x_res,y_res=rm.fit_resample(x,y)

# %%
print("old data set shape{}".format(Counter(y)))
print("old data set shape{}".format(Counter(y_res)))
# Out:
# old data set shapeCounter({0: 6273, 1: 2727})
# old data set shapeCounter({0: 6273, 1: 6273})

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=.2)

# %%
model1=LogisticRegression()
model2= SVC()
model3=RandomForestClassifier(n_estimators=100,class_weight="balanced")
model4=GradientBoostingClassifier(n_estimators=100)

# %%
colums=["LogisticRegression","SVC","RandomForestClassifier","GradientBoostingClassifier"]
result1=[]
result2=[]
result3=[]

# %%
def cal(model):
    model.fit(x_train,y_train)
    pre= model.predict(x_test)
    accuracy =(accuracy_score(pre,y_test))
    recall = recall_score(pre,y_test)
    f1 = f1_score(pre,y_test)

    result1.append(accuracy)
    result2.append(recall)
    result3.append(f1)

    sns.heatmap(confusion_matrix(pre,y_test),annot=True,fmt="d")
    print(model1)
    print("accuracy is :",accuracy,"recall is :",recall,"f1 is :",f1)
cal(model1)
# Out:
# LogisticRegression()
# accuracy is : 0.8344444444444444 recall is : 0.7701149425287356 f1 is : 0.7024463305042437

# %%
cal(model2)
# Out:
# LogisticRegression()
# accuracy is : 0.6973611111111111 recall is : 0.0 f1 is : 0.0

# %%
cal(model3)
# Out:
# LogisticRegression()
# accuracy is : 0.8683333333333333 recall is : 0.7710259797446058 f1 is : 0.7869662921348315

# %%
cal(model4)
# Out:
# LogisticRegression()
# accuracy is : 0.8783333333333333 recall is : 0.8217283950617283 f1 is : 0.7916270218839201

# %%
FinalResult=pd.DataFrame({"Algorithm":colums,"Accuracies": result1 , "Recall": result2, "Fscore":result3})

# %%
fig,ax=plt.subplots(figsize=(20,5))
plt.plot(FinalResult.Algorithm,result1,label="Accuracy")
plt.plot(FinalResult.Algorithm,result2,label="Recall")
plt.plot(FinalResult.Algorithm,result3,label="Fscore")
plt.legend()
plt.show()
